# %%
! pip install -U "autogen-agentchat"

# %%
! pip install -U "autogen-agentchat[openai]"
# Out:
# ...
# WARNING: autogen-agentchat 0.7.5 does not provide the extra 'openai'
# ...

# %%
! pip install autogen-ext

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
# Define a model client. You can use other model client that implements
# the `ChatCompletionClient` interface.
model_client = OpenAIChatCompletionClient(
    model="gemini-2.5-flash",
    api_key="AIzaSyBKZlHOaAF3QV7BZeNkgeHxFt8DzbWWE8Q",
    api_base="https://generativelanguage.googleapis.com/v1beta2/models/gemini-2.5-flash:generateContent",
)

# %%
# Define a simple function tool that the agent can use.
# For this example, we use a fake weather tool for demonstration purposes.
async def get_weather(city: str) -> str:
    """Get the weather for a given city."""
    return f"The weather in {city} is 73 degrees and Sunny."

# %%
# Define an AssistantAgent with the model, tool, system message, and reflection enabled.
# The system message instructs the agent via natural language.
agent = AssistantAgent(
    name="weather_agent",
    model_client=model_client,
    tools=[get_weather],
    system_message="You are a helpful assistant.",
    reflect_on_tool_use=True,
    model_client_stream=True,  # Enable streaming tokens from the model client.
)

# %%
# Run the agent and stream the messages to the console.
import asyncio
async def main() -> None:
    await Console(agent.run_stream(task="What is the weather in New York?"))
    # Close the connection to the model client.
    await model_client.close()


# NOTE: if running this inside a Python script you'll need to use asyncio.run(main()).
await main()
# Out:
# ---------- TextMessage (user) ----------
# What is the weather in New York?
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1603             try:
# -> 1604                 response = await self._client.send(
#    1605                     request,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#    1615         if self._state == ClientState.CLOSED:
# -> 1616             raise RuntimeError("Cannot send a request, as the client has been closed.")
#    1617
#
# RuntimeError: Cannot send a request, as the client has been closed.
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# ...

# %%
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# 1. Model Client Setup
# Google Gemini-ai OpenAI interface vazhiya connect panrom
model_client = OpenAIChatCompletionClient(
    model="gemini-2.5-flash", # Note: Current stable model name use pannunga
    api_key="AIzaSyAn67m-X9YQi9x0_K3UykI25Dp6xOCiBR8", # Unga API key-ai inga podunga
    # Gemini API-kku intha base URL mukkiyam
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# 2. Tool Definition
async def get_weather(city: str) -> str:
    """Get the weather for a given city."""
    return f"The weather in {city} is 73 degrees and Sunny."

# 3. Agent Definition
agent = AssistantAgent(
    name="weather_agent",
    model_client=model_client,
    tools=[get_weather],
    system_message="You are a helpful assistant.",
    reflect_on_tool_use=True,
)

# 4. Main Function to run
async def run_weather_task():
    # Console(agent.run_stream(...)) Colab-la output-ai nalla visual-a kaatum
    await Console(agent.run_stream(task="What is the weather in New York?"))

    # Session mudinja piragu client-ai close pannanum
    await model_client.close()

# Colab (Jupyter) environment-la direct-a await panna mudiyum
await run_weather_task()
# Out:
# ---------- TextMessage (user) ----------
# What is the weather in New York?
# ---------- ToolCallRequestEvent (weather_agent) ----------
# [FunctionCall(id='function-call-17787749285021569271', arguments='{"city":"New York"}', name='get_weather')]
# ---------- ToolCallExecutionEvent (weather_agent) ----------
# [FunctionExecutionResult(content='The weather in New York is 73 degrees and Sunny.', name='get_weather', call_id='function-call-17787749285021569271', is_error=False)]
# ---------- TextMessage (weather_agent) ----------
# The weather in New York is 73 degrees and Sunny.
